# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import scipy
import csv
from scipy.optimize import curve_fit

# %%
px = []
i = []

with open('d.dat') as data:
    csv_reader = csv.reader(data, delimiter=' ')

    for line in csv_reader:
        px.append(float(line[0]))
        i.append(float(line[1]))

px = np.array(px)
i = np.array(i)

# %%
plt.plot(px,i)
plt.xlabel('Pixels')
plt.ylabel('Relative intensity')
plt.show()

# %%
s = 656.279-653.288

# %%
np.where(i==max(i))
# Out:
# (array([1101]),)

# %%
np.where(i==max(i[:200]))
# Out:
# (array([74]),)

# %%
sc = s/(1101-74)

# %%
b = 653.279-74*sc

# %%
wl = px*sc+b

# %%
plt.plot(wl,i)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Relative intensity')
plt.show()

# %%
wl[np.where(i==max(i[:1050]))]
# Out:
# array([656.09234567])

# %%
sc
# Out:
# 0.0029123661148977463
