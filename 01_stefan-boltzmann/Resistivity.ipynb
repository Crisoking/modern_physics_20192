# %% [markdown]
# # Resistividad vs. Temperatura del tungsteno
#
# La siguiente tabla muestra la relación entre la resistividad y la temperatura del tungsteno:

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import scipy
# from scipy import linalg as lin
# from scipy import stats
import scipy.interpolate as intrp
from matplotlib import rc
# import sys
# import re
# import pandas as pd
temp=np.linspace(300,3600,num = 34)
rest=np.array([5.65,8.06,10.56,13.23,16.09,19,21.94,24.93,27.94,30.98,34.08,37.19,40.36,43.55,46.78,50.05,
              53.35,56.67,60.06,63.48,66.91,70.39,73.91,77.49,81.04,84.7,88.33,92.04,95.76,99.54,103.3,
              107.2,111.1,115.0])

# %%
z= np.polyfit(rest,temp,7)
f=np.poly1d(z)
z= np.polyfit(temp,rest,7)
finv=np.poly1d(z)
temp1=np.linspace(250,3800,num = 60)
tempt=np.array([f(x) for x in rest])
rest1=np.array([finv(x) for x in temp])

# %%
plt.subplot(1,2,1)
plt.plot(rest,temp,'g^')
plt.plot(rest,tempt,'r')
plt.ylabel('Temperatura (K)')
plt.xlabel(r'Resistividad ($\times 10^{-8} \Omega\cdot$m)')

plt.subplot(1,2,2)
plt.plot(rest,tempt-temp,'o')
plt.xlabel('Resistividad')
plt.ylabel('Residual de Temperatura (K)')
plt.tight_layout

plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(temp,rest, 'D')
plt.plot(temp,rest1, 'r')

plt.subplot(1,2,2)
plt.plot(temp,rest-rest1, 'o')
plt.show()

# %%
data = np.array([ 5.57421053,  5.63755383,  5.67755478,  5.76765875,  5.88834374,
        6.03227566,  6.23560504,  6.41569916,  6.83155752,  7.04934705,
        7.27929258,  7.50164571,  7.6413959 ,  7.87574079,  8.09554975,
        8.30400086,  8.7293247 ,  8.6637435 ,  8.97492925,  9.16933109,
        9.30963293,  9.75309783,  9.89186048, 10.08068902, 10.30253228,
       10.37399456, 10.61528568, 10.77136706, 10.96267152, 11.18631436,
       11.37592038, 11.51139144, 11.6839214 , 11.80095805, 11.95814754,
       12.07444456, 12.23019899, 12.3816566 , 12.29001119, 12.4619032 ,
       12.5555268 , 12.40758145, 12.53391886, 12.60977908, 12.77594337,
       12.86093539, 12.99701525, 13.15305754, 13.29827113, 13.37885688,
       13.52581297, 13.64694705, 13.76539225, 13.86601647, 14.1249267 ,
       14.20463408, 14.34356333, 14.39594229, 14.53775564, 14.66209833,
       14.74627666, 14.78350131, 14.98434786, 15.00267958, 15.02047214,
       15.11074774, 15.27271379, 15.35927978, 15.44420471, 15.5275348 ,
       15.60931457, 15.76222385, 15.84072509, 15.91779904, 16.06585298,
       16.13987098, 16.28495066, 16.28399413, 16.42589643, 16.63367889,
       16.69964611, 20.03680131, 20.16137803, 20.2789188 , 20.43099018,
       20.69033138, 20.83596934, 21.00058534, 21.0813644 , 21.26417362,
       21.34164168, 21.47677605, 21.5229189 , 21.68431652, 21.75746496,
       21.95808146, 22.02090364, 22.23438596, 22.49665777, 22.67058138,
       22.81404623, 19.81415813, 20.06506572, 20.48396255, 20.77459682,
       21.02599542, 21.3165313 , 21.46467013, 21.74392157, 22.21447695,
       0.88247135, 0.88842992, 0.89573987, 0.89733457, 0.90131397,
       0.9042905 , 0.90651024, 0.91133883, 0.91310304, 0.91908078,
       0.92173645, 0.92523499, 0.93073578, 0.93407829, 0.93862804,
       0.94498518, 0.95118945, 0.95248455, 0.96010645, 0.9644855 ,
       0.96794459, 0.97323401, 0.98391613, 0.98697548, 0.99323426,
       1.00000543, 0.99450036, 1.00209229, 1.00933368, 1.01262471,
       1.01427285, 1.0247285 , 1.01438029, 1.03257693, 1.03733042,
       1.04512513, 1.05072738, 1.05767602, 1.06230468, 1.06501688,
       1.07249909, 1.08036999, 1.08186376, 1.088803  , 1.09810592,
       1.10895539, 1.09735977, 1.10575589, 1.11391727, 1.11958965,
       1.12258522, 1.12591158, 1.13175711, 1.1356974 , 1.13888425,
       1.14272983, 1.14754718, 1.15198816, 1.15675694, 1.15632295,
       1.16103213, 1.16626911, 1.16881996, 1.17299245, 1.17720203,
       1.18270425])

# %%
unc_temp = T_prime(data)*unc_rest

# %%
unc_temp
# Out:
# array([11.50797328,  7.92328042,  6.77792328,  6.22246285,  5.95610912,
#         5.80843003,  5.79403157,  5.78510245,  5.96939638,  6.03680857,
#         6.12311379,  6.20202   ,  6.24495543,  6.34463569,  6.44469571,
#         6.53653917,  6.77489524,  6.69187353,  6.8579584 ,  6.94967614,
#         7.0097228 ,  7.23104424,  7.28521727,  7.3755248 ,  7.4866485 ,
#         7.5118441 ,  7.63079459,  7.70662821,  7.8033657 ,  7.91783287,
#         8.00849757,  8.07290159,  8.1513651 ,  8.20912925,  8.28234009,
#         8.33930858,  8.41369482,  8.48343654, 10.46078448, 10.50679945,
#        10.52415925, 10.54376878, 10.56948558, 10.56189992, 10.61883812,
#        10.62126599, 10.66033692, 10.71420397, 10.76180358, 10.76715211,
#        10.81817961, 10.85299185, 10.88705296, 10.91039333, 11.03821019,
#        11.04949923, 11.10020929, 11.09576047, 11.14988136, 11.19341269,
#        11.21197062, 11.20147686, 13.71352494, 13.65892963, 13.60587425,
# ...

# %%
data_s = np.array([  9.7260758 ,  19.84067153,  24.9085899 ,  27.12978956,
        36.08265535,  37.30703902,  45.25637678,  53.32048225,
        62.54584759,  68.90710111,  78.35282053,  90.97714497,
       100.78755479])

# %%
temp_s = f(data_s)

# %%
temp_s
# Out:
# array([ 466.40610619,  830.22065573, 1000.21542539, 1073.46412521,
#        1363.530863  , 1402.62843251, 1652.9231571 , 1899.84930664,
#        2173.39455173, 2357.103475  , 2624.12929789, 2971.90383403,
#        3233.49000744])

# %%
unc_rest_s=np.array([0.56936957, 0.60227118, 0.78779238, 0.89880697, 0.8233337 ,
       0.94632821, 1.24568748, 1.69067518, 1.50439427, 1.52895158,
       1.85311001, 2.72953182, 2.18669786])

# %%
unc_temp_s=T_prime(data_s)*unc_rest_s

# %%
unc_temp_s
# Out:
# array([22.09215718, 20.50929036, 26.092396  , 29.51880359, 26.33715416,
#        30.16525222, 38.70827745, 50.99079095, 43.88236076, 43.74116802,
#        51.80789486, 73.96537854, 57.30506978])
